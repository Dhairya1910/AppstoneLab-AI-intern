Rohit Sharma's batting style is a captivating blend of grace, timing, and raw aggression. His initial approach at the crease is often measured, allowing him to get set, assess the pitch conditions, and understand the bowlers' strategies. Once he is settled, he unleashes a breathtaking array of strokes, characterized by exquisite timing, powerful pull shots, and elegant drives through the off-side. His ability to accelerate seamlessly from a steady start to an explosive finish, shifting gears almost imperceptibly, makes him a nightmare for opposition bowlers. His calm and composed demeanor at the crease, even under immense pressure, is another defining characteristic, often belying the destructive power he wields. He doesn't appear to muscle the ball; rather, he times it with such precision that it sails over the boundary ropes with minimal apparent effort. This 'effortless' quality is, as he himself has stated, the result of immense dedication and countless hours of practice, dispelling the myth of purely "natural talent."
His career has not been without its share of challenges and periods of adversity, which he has consistently overcome with remarkable resilience. He has battled significant injuries, most notably a major hamstring injury in late 2016 that kept him out of competitive cricket for six months. Making a comeback from such a layoff is never easy, but Rohit's mental fortitude shone through. He often speaks about conquering his "inner demons" during these phases, focusing on rehabilitation and returning stronger. His ability to compartmentalize and focus on the task at hand, whether leading his IPL team or making a national comeback, has been crucial to his longevity and success. Even in Test cricket, where he faced initial struggles, his unwavering belief in his ability and his willingness to adapt to the demands of opening the innings ultimately led to his success in the format. His journey serves as a powerful inspiration, demonstrating that perseverance, hard work, and a strong mindset can overcome even the most formidable obstacles. He has also been a mentor to many young cricketers, often seen offering advice and guidance, and his philosophy on hard work over innate talent resonates deeply with aspiring athletes.
In conclusion, Rohit Gurunath Sharma's journey in international cricket is a compelling and multifaceted narrative of perseverance, dramatic transformation, and unparalleled success. From an early prodigy who navigated periods of inconsistency to emerge as 'The Hitman' who rewrote batting records in white-ball cricket, and then to a highly successful captain across formats, his career arc is truly inspiring. His unique feat of three double centuries in ODIs, his record-breaking seven centuries in a single Cricket World Cup edition, his status as the leading six-hitter in international cricket, and his five IPL titles as captain are just a few highlights of a career brimming with extraordinary achievements. Beyond the sheer weight of statistics and records, it is his elegant yet destructive batting, his calm and astute leadership, and his unwavering ability to perform under the most intense pressure that have endeared him to millions of fans worldwide. Rohit Sharma is not merely a cricketer; he is an icon, a transformative leader, and a true legend of the game whose enduring legacy will continue to inspire generations of aspiring cricketers and sports enthusiasts, solidifying his place among the pantheon of cricketing greats."""

# %%
import numpy as np
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Input,LSTM,Embedding,BatchNormalization
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
def Sentence_tokenizer(paragraph):
  Input_sequences = []
  tokenizer = Tokenizer()
  tokenizer.fit_on_texts([paragraph])
  print(tokenizer.word_index)
  for sentence in paragraph.split('\n'):
    tokenizied_sentence = tokenizer.texts_to_sequences([sentence])[0]

    for char in range(1,len(tokenizied_sentence)):
      Input_sequences.append(tokenizied_sentence[:char+1])
  max_len = max([len(x) for x in Input_sequences])
  padded_input = pad_sequences(Input_sequences,maxlen=max_len,padding='pre')
  return padded_input,tokenizer

# %%
padded_input_seqeunces,tokenizer = Sentence_tokenizer(paragraph)
# Out:
# {'the': 1, 'his': 2, 'in': 3, 'a': 4, 'and': 5, 'to': 6, 'of': 7, 'he': 8, 'that': 9, 'cricket': 10, 'with': 11, 'for': 12, 'as': 13, 'an': 14, 'was': 15, 'on': 16, 'is': 17, 'ability': 18, 'him': 19, 'rohit': 20, 'from': 21, 'against': 22, 'world': 23, 'test': 24, 'this': 25, 'cup': 26, 'at': 27, 'has': 28, 'batting': 29, 'team': 30, 'international': 31, 'ball': 32, 'most': 33, 'often': 34, 'career': 35, 'innings': 36, 'india': 37, 'format': 38, 'record': 39, 'into': 40, 'history': 41, 'by': 42, 'it': 43, 'captain': 44, 'odi': 45, 'centuries': 46, 'ipl': 47, 'talent': 48, 'leadership': 49, 'significant': 50, 'led': 51, 'trophy': 52, 't20': 53, 'success': 54, '2019': 55, 'indian': 56, 'remarkable': 57, 'mumbai': 58, 'early': 59, 'white': 60, 'one': 61, "rohit's": 62, 'play': 63, 'crucial': 64, 'debut': 65, 'icc': 66, 'under': 67, 'consistent': 68, 'who': 69, '2013': 70, 'been': 71, 'where': 72, 'sharma': 73, 'not': 74, 'off': 75, 'power': 76, 'even': 77, 'runs': 78, 'first': 79, 'per
# ...

# %%
X = padded_input_seqeunces[:,:-1]
Y = padded_input_seqeunces[:,-1]
print(X.shape)
print(Y.shape)
# Out:
# (2715, 280)
# (2715,)

# %%
Y_encoded = to_categorical(Y,num_classes=950)

# %%
model = Sequential()
model.add(Embedding(950,150,input_length=280))
model.add(LSTM(256))
model.add(Dense(512,activation='relu'))
model.add(Dense(950,activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['Accuracy'])

# %%
model.fit(
    X,
    Y_encoded,
    epochs = 25
)
# Out:
# Epoch 1/25
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - Accuracy: 0.0360 - loss: 6.5129
# Epoch 2/25
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - Accuracy: 0.0551 - loss: 5.8945
# Epoch 3/25
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - Accuracy: 0.0483 - loss: 5.6546
# Epoch 4/25
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - Accuracy: 0.0482 - loss: 5.4892
# Epoch 5/25
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - Accuracy: 0.0712 - loss: 5.2715
# Epoch 6/25
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - Accuracy: 0.0879 - loss: 5.0830
# Epoch 7/25
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - Accuracy: 0.0977 - loss: 4.7508
# Epoch 8/25
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - Accuracy: 0.1256 - loss: 4.4689
# Epoch 9/25
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - Accuracy: 0.1568 - loss: 4.0813
# Epoch 10/25
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - Accuracy: 0.2076 - loss: 3.6565
# Epoch 11/25
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - Accuracy: 0.2726 - loss: 3.1789
# Epoch 12/25
# ...

# %% [markdown]
# # Testing Part|

# %%
txt = input("Ask about Rohit Sharma \t")

for i in range(25):
  token_text = tokenizer.texts_to_sequences([txt])[0]
  padded_token_text = pad_sequences([token_text],maxlen=280,padding='pre')
  pos = np.argmax(model.predict(padded_token_text))
  for word,index in tokenizer.word_index.items():
    if index == pos:
      txt = txt + " " + word

print(txt)
# Out:
# Ask about Rohit Sharma 	how many international century
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ...
